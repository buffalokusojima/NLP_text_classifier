# %%
from wakati import wakati_class
from tfidf import tfidf_class
from Dictionary import dictionary_class

ROOT_DIR = '.'
DATA_PATH = './text'
DATA_FILE_NAME = '.txt'
OUTPUT_PATH = './dictionary_test'

#wakati = wakati_class.Wakati(DATA_FILE_NAME, ROOT_DIR, ROOT_DIR)

#wakati.show_path()
#wakati.wakati()


#tfidf = tfidf_class.TF_IDF(ROOT_DIR, DATA_PATH, ROOT_DIR+OUTPUT_PATH, 0.03, 0.5, 500)
#tfidf.show_path()
#tfidf.tfidf_medium()

dictionary = dictionary_class.Dictionary(DATA_PATH, OUTPUT_PATH)
dictionary.show_path()
# Out:
# ./text ./dictionary_test

# %%
import os
dictionary.make_word_list_folder(os.path.join(DATA_PATH,"dokujo-tsushin"), OUTPUT_PATH)
# Out:
# ./dictionary_test/dokujo-tsushin

# %%
import pickle
with open("./dictionary_test/dokujo-tsushin/word_list.pkl", "rb") as f:
    file = pickle.load(f)

print(file[0])
# Out:
# {'text': ['花粉', 'シーズン', '到来', '前', 'ビフィズス', '菌', '習慣', '暖冬', '思う', 'しまう', '冷え込み', '続く', '2', '月', '積雪', '観測', 'する', 'れる', 'ひと言', '尽きる', '季節', 'なる', 'つぶやく', 'しまう', '春', '来る', 'の', '憂鬱', '感じる', '恐れる', 'いる', '人', 'いる', '春', '花粉', '症', '季節', 'ある', '花粉', '症', '多種', '多様', '花粉', '体内', '入る', 'こと', '体', '拒否', '反応', '起こす', 'アレルギー', '一種', '鼻水', 'くしゃみ', 'せく', '目', '炎症', '症状', 'アレルギー', '反応', '起きる', 'いる', 'の', '気象', 'サイト', 'ウェザーニュース', '発表', '2011', '年', '花粉', '飛散', '傾向', '調査', 'よる', '今春', '花粉', '飛散', '量', '全国', '的', '昨年', '5', '倍', '見込み', 'なる', 'いる', '7', '8', '倍', '10', '倍', '予想', 'する', 'れる', 'いる', 'の', '昨年', '猛暑', '影響', '見る', '頭', 'する', 'そう', '調査', '結果', 'なる', 'いる', '発表', 'スギ', '花粉', 'こと', 'スギ', '以外', '花粉', 'アレルギー', '併発', 'する', '人', '脅威', '大量', '花粉', '飛散', 'する', '対策', '行う', 'こと', '重要', '対策', 'ひと言', 'いう', 'こだわり', 'マスク', '完全', '防備', 'ゴーグル', '花粉', '体内', '入れる', 'ため', '鼻', '用', '軟膏', 'さまざま', '症状', '抑える', '薬', '販売', 'する', 'れる', 'いる', '対策', 'いう', '2010', '年度', '農芸', '化', '学会', '発表', '行う', 'れる', 'それ', '
# ...

# %%
dictionary.make_medium_dictionary()
# Out:
# ./dictionary_test
# ./dictionary_test/movie-enter
# ./dictionary_test
# ./dictionary_test/it-life-hack
# ./dictionary_test
# ./dictionary_test/kaden-channel
# ./dictionary_test
# ./dictionary_test/topic-news
# ./dictionary_test
# ./dictionary_test/livedoor-homme
# ./dictionary_test
# ./dictionary_test/peachy
# ./dictionary_test
# ./dictionary_test/sports-watch
# ./dictionary_test
# ./dictionary_test/dokujo-tsushin
# ./dictionary_test
# ./dictionary_test/smax
# /usr/local/lib/python3.7/site-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
with open("./dictionary_test/smax/word_list.pkl", "rb") as f:
    file = pickle.load(f)

print(file[0])
# Out:
# {'text': ['最近', 'オススメ', 'アプリ', '特集', '2012', '年', '4', '月', '16', '20', '日', '編', '2012', '年', '4', '月', '16', '20', '日', '紹介', 'する', 'Android', 'アプリ', 'NTT', 'KDDI', '2012', '年', '夏', 'モデル', '発表', 'する', 'れる', '搭載', '17', '機種', '18', 'モデル', '事前', '発表', 'する', 'れる', 'いる', 'J', 'ISW', '13', '含める', 'au', '向け', 'Android', '搭載', '6', '機種', '発表', 'する', 'れる', 'J', 'ISW', '13', 'HT', '25', '日', '金', '発売', '予定', 'なる', '29', '日', '火', 'ウィルコム', '合同', '2012', '年', '夏', 'モデル', '発表', '会', '行う', 'こと', 'こちら', 'ウィルコム', '向け', 'PHS', '3', 'G', 'デュアル', '搭載', 'Android', 'フォン', '含める', 'Android', '搭載', '機', '多数', '発表', 'する', 'れる', 'そう', '状況', '通る', 'ここ', '最近', '-', 'MAX', '紹介', 'する', 'Android', 'アプリ', 'まとめる', 'いる', '見逃す', 'いる', 'アプリ', 'ある', 'しれる', 'エスマックス', '読む', 'いる', '人', '人', 'さらう', '読む', 'もらえる', '思う', '見る', 'いく', '間近', '非常', 'シンプル', 'カウントダウンアプリ', '金環', '日食', 'NAVI', '明後日', '２', '１', '日', '月', '早朝', '起こる', '世紀', '一大', 'イベント', '金環', '日食', 'ここ', '国内', '範囲', 'カバー', 'する', 'の', '数', '百', '年', 'ぶり', '言う', 'れる'
# ...
